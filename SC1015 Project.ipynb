# %% [markdown]
# ## SC1015 Project (Group 5)

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()

# %%
dataset = pd.read_csv("heart_2020_cleaned.csv")

# %%
dataset
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# ## maleDataSet

# %%
maleDataset = dataset[dataset["Sex"] == "Male"]

# %%
maleDataset
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 2                No  26.58     Yes              No     No            20.0
# 9                No  40.69      No              No     No             0.0
# 10              Yes  34.30     Yes              No     No            30.0
# 12               No  28.37     Yes              No     No             0.0
# 17               No  22.59     Yes              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 319784           No  26.58     Yes              No     No             0.0
# 319785           No  31.93      No             Yes     No             0.0
# 319787           No  36.54      No              No     No             7.0
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
#
#         MentalHealth DiffWalking   Sex AgeCategory      Race  \
# ...

# %%
maleAmericanIndianAlaskanNative = maleDataset[maleDataset["Race"] == "American Indian/Alaskan Native"]

# %%
maleAmericanIndianAlaskanNative
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 75               No  25.54     Yes              No    Yes             0.0
# 166              No  23.01     Yes              No     No            30.0
# 268              No  38.01      No              No     No             4.0
# 1122             No  32.55      No              No     No             0.0
# 1311            Yes  44.86     Yes              No     No            30.0
# ...             ...    ...     ...             ...    ...             ...
# 312441           No  31.19     Yes              No     No             0.0
# 312779           No  26.63     Yes             Yes     No             0.0
# 312936           No  29.41      No              No     No             0.0
# 313071           No  40.90     Yes              No     No             0.0
# 313205           No  26.69     Yes              No     No             0.0
#
#         MentalHealth DiffWalking   Sex  AgeCategory  \
# ...

# %%
maleAsian = maleDataset[maleDataset["Race"] == "Asian"]

# %%
maleAsian
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 69               No  40.00      No              No     No             0.0
# 405              No  25.80      No              No     No             0.0
# 1087            Yes  20.36      No              No     No            10.0
# 1337             No  23.03     Yes              No     No             0.0
# 2720             No  26.63      No              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 315351           No  31.78      No              No     No             0.0
# 315377           No  29.13     Yes              No     No             0.0
# 315383           No  24.21     Yes             Yes     No             0.0
# 315385           No  23.59      No              No     No             0.0
# 315707           No  29.39      No              No     No             0.0
#
#         MentalHealth DiffWalking   Sex AgeCategory   Race Diabetic  \
# ...

# %%
maleBlack = maleDataset[maleDataset["Race"] == "Black"]

# %%
maleBlack
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 30               No  25.84     Yes              No     No             5.0
# 136              No  45.33      No              No     No            15.0
# 139              No  33.20      No              No     No            16.0
# 142             Yes  31.48      No             Yes    Yes            20.0
# 143              No  34.01     Yes              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 314863           No  31.57      No              No     No            12.0
# 314947           No  29.05      No              No     No             0.0
# 315307           No  24.01      No              No     No             0.0
# 315344           No  47.42      No              No     No             0.0
# 315387           No  28.75      No              No     No             0.0
#
#         MentalHealth DiffWalking   Sex AgeCategory   Race  \
# ...

# %%
maleHispanic = maleDataset[maleDataset["Race"] == "Hispanic"]

# %%
maleHispanic
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 223              No  31.66      No              No     No             0.0
# 357              No  25.83      No              No     No             0.0
# 951              No  27.89     Yes              No     No             0.0
# 1166             No  35.67     Yes              No     No            30.0
# 1172             No  23.81      No              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 319784           No  26.58     Yes              No     No             0.0
# 319785           No  31.93      No             Yes     No             0.0
# 319787           No  36.54      No              No     No             7.0
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
#
#         MentalHealth DiffWalking   Sex AgeCategory      Race  \
# ...

# %%
maleWhite = maleDataset[maleDataset["Race"] == "White"]

# %%
maleWhite
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 2                No  26.58     Yes              No     No            20.0
# 9                No  40.69      No              No     No             0.0
# 10              Yes  34.30     Yes              No     No            30.0
# 12               No  28.37     Yes              No     No             0.0
# 17               No  22.59     Yes              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 316476          Yes  34.30      No              No     No             1.0
# 316952           No  22.24      No              No     No             0.0
# 318533           No  26.17     Yes              No     No             0.0
# 319034           No  26.50     Yes              No     No             0.0
# 319603          Yes  35.51      No              No     No            30.0
#
#         MentalHealth DiffWalking   Sex AgeCategory   Race  \
# ...

# %%
maleOther = maleDataset[maleDataset["Race"] == "Other"]

# %%
maleOther
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 105              No  58.54      No              No     No            30.0
# 531              No  25.09     Yes              No     No             0.0
# 803              No  25.24     Yes              No     No             0.0
# 1081             No  21.77      No              No     No             0.0
# 1195             No  28.43      No              No     No            21.0
# ...             ...    ...     ...             ...    ...             ...
# 315748           No  19.80     Yes              No     No             0.0
# 315827           No  25.02     Yes              No     No             0.0
# 316654           No  19.80     Yes              No     No             0.0
# 317899           No  40.29     Yes              No     No             0.0
# 317973           No  27.44     Yes              No     No             0.0
#
#         MentalHealth DiffWalking   Sex  AgeCategory   Race  \
# ...

# %% [markdown]
# ## Progress:
# We made 2 partitions: Male and Female Dataset
# Additional 6 partitions down each gender's dataset; mainly race categories.
# 1. maleAmericanIndianAlaskanNative
# 2. maleAsian
# 3. maleBlack
# 4. maleHispanic
# 5. maleWhite
# 6. maleOther

# %%
labels = ['American Indian/Alskan Native', 'Asian', 'Black', 'Hispanic', 'White','Other']
sizes = [maleAmericanIndianAlaskanNative.size, maleAsian.size, maleBlack.size, maleHispanic.size, maleWhite.size, maleOther.size]

plt.rcParams.update({'font.size': 30})
plt.axis("equal")

plt.pie(sizes,labels = labels, radius = 5, autopct = "%0.1f%%")
plt.show()

# %% [markdown]
# ## femaleDataset

# %%
femaleDataset = dataset[dataset["Sex"] == "Female"]

# %%
femaleAmericanIndianAlaskanNative = femaleDataset[femaleDataset["Race"] == "American Indian/Alaskan Native"]

# %%
femaleAmericanIndianAlaskanNative
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 318              No  25.75     Yes              No     No             5.0
# 382              No  34.45      No              No    Yes             0.0
# 420              No  30.11     Yes              No     No             0.0
# 559             Yes  24.19      No              No    Yes            30.0
# 765              No  37.12     Yes              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 312972           No  22.86      No              No     No             0.0
# 313137           No  28.97     Yes              No     No             1.0
# 313223           No  38.62     Yes              No     No             0.0
# 313319           No  29.29     Yes              No     No             0.0
# 313405          Yes  41.01     Yes              No    Yes            14.0
#
#         MentalHealth DiffWalking     Sex AgeCategory  \
# ...

# %%
femaleAsian = femaleDataset[femaleDataset["Race"] == "Asian"]

# %%
femaleAsian
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 160              No  17.71      No              No     No             0.0
# 856              No  25.61      No              No     No             0.0
# 1115             No  20.60     Yes              No     No             0.0
# 2384             No  28.32      No              No     No             0.0
# 2387             No  20.90     Yes              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 315397           No  23.80      No              No     No             0.0
# 315402           No  25.61      No              No     No            30.0
# 315404           No  23.83      No              No     No             0.0
# 317066           No  24.03      No             Yes     No             0.0
# 318746           No  27.44      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex AgeCategory   Race  \
# ...

# %%
femaleBlack = femaleDataset[femaleDataset["Race"] == "Black"]

# %%
femaleBlack
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 5               Yes  28.87     Yes              No     No             6.0
# 18               No  29.86     Yes              No     No             0.0
# 20               No  21.16      No              No     No             0.0
# 34               No  38.97      No              No     No             0.0
# 39               No  21.93      No              No     No             3.0
# ...             ...    ...     ...             ...    ...             ...
# 314745           No  25.75      No              No     No             0.0
# 315141           No  48.26      No              No     No             0.0
# 315184           No  44.29      No              No     No             0.0
# 315242           No  22.32      No              No     No             0.0
# 315415           No  24.09      No             Yes     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# ...

# %%
femaleHispanic = femaleDataset[femaleDataset["Race"] == "Hispanic"]

# %%
femaleHispanic
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 422              No  25.85      No              No     No             0.0
# 438              No  38.09      No              No     No             4.0
# 1204             No  28.91     Yes              No     No             0.0
# 1334             No  18.54     Yes              No     No             0.0
# 1389             No  40.17      No              No     No             7.0
# ...             ...    ...     ...             ...    ...             ...
# 319788           No  23.38      No              No     No             0.0
# 319789           No  22.22      No              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
femaleWhite = femaleDataset[femaleDataset["Race"] == "White"]

# %%
femaleWhite
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# 6                No  21.63      No              No     No            15.0
# ...             ...    ...     ...             ...    ...             ...
# 318296           No  27.44     Yes              No     No             0.0
# 318487           No  28.35      No              No     No             0.0
# 318586           No  24.89      No              No     No             0.0
# 318636           No  49.92      No              No     No             0.0
# 319055           No  28.32      No              No     No            10.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# ...

# %%
femaleOther = femaleDataset[femaleDataset["Race"] == "Other"]

# %%
femaleOther
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 141             Yes  29.29     Yes              No     No             0.0
# 297             Yes  27.29     Yes              No    Yes            30.0
# 332              No  34.19      No              No     No             0.0
# 448              No  25.00      No              No     No             0.0
# 486              No  33.47      No              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 317151           No  29.18      No              No     No            30.0
# 317386           No  28.73     Yes              No     No             0.0
# 318622           No  26.61      No              No     No             0.0
# 318724          Yes  33.81      No              No     No             0.0
# 319477           No  25.82      No              No     No            30.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# ...

# %%
labels = ['American Indian/Alskan Native', 'Asian', 'Black', 'Hispanic', 'White','Other']
sizes = [femaleAmericanIndianAlaskanNative.size, femaleAsian.size, femaleBlack.size, femaleHispanic.size, femaleWhite.size, femaleOther.size]

plt.rcParams.update({'font.size': 30})
plt.axis("equal")

plt.pie(sizes,labels = labels, radius = 5, autopct = "%0.1f%%")
plt.show()
